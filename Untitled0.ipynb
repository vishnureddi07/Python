# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({'Age':[1,4,7,9,3,2,6,80]})
df
# Out:
#    Age
# 0    1
# 1    4
# 2    7
# 3    9
# 4    3
# 5    2
# 6    6
# 7   80

# %%
plt.figure(figsize=(5,3))
sns.boxplot(x = df['Age'])
# Out:
# <Axes: xlabel='Age'>
