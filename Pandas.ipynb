# %% [markdown]
# **Pandas -> is used for Data Manipulation**

# %%
import numpy as np
import pandas as pd

# %%
len(dir(pd))
# Out:
# 141

# %% [markdown]
# **Some Pandas Built_in_Functions for AI**
#
# - `Series `
# - `DataFrame `
# - `shape `
# - `size `
# - `drop `
# - `rename `
# - `axis = 1`
# - `axis = 0 `
# - `fillna `
# - `dropna `
# - `info `
# - `select_dtypes `
# - `isnull().sum()`
# - `unique `
# - `value_counts`
# - `GroupBy`
# - `to_csv`
# - `read_csv `
# - `loc and iloc `

# %%
# Series = which is used to create only 1 column representation

b = np.array([10,20,30,40,50]) # 1d

a = pd.Series(b) # 1D giving to Series Function

a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
a[2]
# Out:
# np.int64(30)

# %% [markdown]
# - `But In real time we are going to work with More than one column `
# - `Series is used to create only 1 Column representation but If we want to create Multiple columns we have a function in pandas library called DataFrame `

# %%
# DataFrame

a = {'Name':['John','peter','Steve','Brad','Smith','Hussy'],
     'Age':[27,29,30,32,33,38],
     'Loc':['USA','UK','Paris','Canada','India','Dubai'],
     'Experiece':[1,2,4,6,8,3],
     'Salary':[1200,1400,1900,2100,900,800]
     }


b = pd.DataFrame(a)
b
# Out:
#     Name  Age     Loc  Experiece  Salary
# 0   John   27     USA          1    1200
# 1  peter   29      UK          2    1400
# 2  Steve   30   Paris          4    1900
# 3   Brad   32  Canada          6    2100
# 4  Smith   33   India          8     900
# 5  Hussy   38   Dubai          3     800

# %%
b['Name'][1]
# Out:
# 'peter'

# %%
b['Loc'][3]
# Out:
# 'Canada'

# %%
b.loc[1:3 , 'Age':'Experiece']
# Out:
#    Age     Loc  Experiece
# 1   29      UK          2
# 2   30   Paris          4
# 3   32  Canada          6

# %%
b.loc[0:3 , 'Loc':'Experiece']
# Out:
#       Loc  Experiece
# 0     USA          1
# 1      UK          2
# 2   Paris          4
# 3  Canada          6

# %%
b
# Out:
#     Name  Age     Loc  Experiece  Salary
# 0   John   27     USA          1    1200
# 1  peter   29      UK          2    1400
# 2  Steve   30   Paris          4    1900
# 3   Brad   32  Canada          6    2100
# 4  Smith   33   India          8     900
# 5  Hussy   38   Dubai          3     800

# %%
b.loc[1:4 , 'Age':'Experiece']
# Out:
#    Age     Loc  Experiece
# 1   29      UK          2
# 2   30   Paris          4
# 3   32  Canada          6
# 4   33   India          8

# %%
b.iloc[1:5 , 1:4]
# Out:
#    Age     Loc  Experiece
# 1   29      UK          2
# 2   30   Paris          4
# 3   32  Canada          6
# 4   33   India          8

# %%
b
# Out:
#     Name  Age     Loc  Experiece  Salary
# 0   John   27     USA          1    1200
# 1  peter   29      UK          2    1400
# 2  Steve   30   Paris          4    1900
# 3   Brad   32  Canada          6    2100
# 4  Smith   33   India          8     900
# 5  Hussy   38   Dubai          3     800

# %%
b.loc[1:3 , 'Name':'Experiece']
# Out:
#     Name  Age     Loc  Experiece
# 1  peter   29      UK          2
# 2  Steve   30   Paris          4
# 3   Brad   32  Canada          6

# %%
b.iloc[1:4 , 0:4]
# Out:
#     Name  Age     Loc  Experiece
# 1  peter   29      UK          2
# 2  Steve   30   Paris          4
# 3   Brad   32  Canada          6

# %%
b
# Out:
#     Name  Age     Loc  Experiece  Salary
# 0   John   27     USA          1    1200
# 1  peter   29      UK          2    1400
# 2  Steve   30   Paris          4    1900
# 3   Brad   32  Canada          6    2100
# 4  Smith   33   India          8     900
# 5  Hussy   38   Dubai          3     800

# %%
b = b.rename(columns={'Loc':'Area'})

# %%
b
# Out:
#     Name  Age    Area  Experiece  Salary
# 0   John   27     USA          1    1200
# 1  peter   29      UK          2    1400
# 2  Steve   30   Paris          4    1900
# 3   Brad   32  Canada          6    2100
# 4  Smith   33   India          8     900
# 5  Hussy   38   Dubai          3     800

# %%
# axis = 1 -> column
# axis = 0 -> row

# %%
b = b.drop(['Experiece'],axis=1)

# %%
b
# Out:
#     Name  Age    Area  Salary
# 0   John   27     USA    1200
# 1  peter   29      UK    1400
# 2  Steve   30   Paris    1900
# 3   Brad   32  Canada    2100
# 4  Smith   33   India     900
# 5  Hussy   38   Dubai     800

# %%
b['Age'] = [10,10,10,20,30,30]

# %%
b
# Out:
#     Name  Age    Area  Salary
# 0   John   10     USA    1200
# 1  peter   10      UK    1400
# 2  Steve   10   Paris    1900
# 3   Brad   20  Canada    2100
# 4  Smith   30   India     900
# 5  Hussy   30   Dubai     800

# %%
b['EMI'] = [10,20,10,20,10,4]

# %%
b
# Out:
#     Name  Age    Area  Salary  EMI
# 0   John   10     USA    1200   10
# 1  peter   10      UK    1400   20
# 2  Steve   10   Paris    1900   10
# 3   Brad   20  Canada    2100   20
# 4  Smith   30   India     900   10
# 5  Hussy   30   Dubai     800    4

# %%
b['TAX'] = [100,200,np.nan,300,400,np.nan]

# %%
b
# Out:
#     Name  Age    Area  Salary  EMI    TAX
# 0   John   10     USA    1200   10  100.0
# 1  peter   10      UK    1400   20  200.0
# 2  Steve   10   Paris    1900   10    NaN
# 3   Brad   20  Canada    2100   20  300.0
# 4  Smith   30   India     900   10  400.0
# 5  Hussy   30   Dubai     800    4    NaN

# %%
b.size
# Out:
# 36

# %%
b.shape
# Out:
# (6, 6)

# %%
b
# Out:
#     Name  Age    Area  Salary  EMI    TAX
# 0   John   10     USA    1200   10  100.0
# 1  peter   10      UK    1400   20  200.0
# 2  Steve   10   Paris    1900   10    NaN
# 3   Brad   20  Canada    2100   20  300.0
# 4  Smith   30   India     900   10  400.0
# 5  Hussy   30   Dubai     800    4    NaN

# %%
b.isnull().sum()
# Out:
# Name      0
# Age       0
# Area      0
# Salary    0
# EMI       0
# TAX       2
# dtype: int64

# %%
b
# Out:
#     Name  Age    Area  Salary  EMI    TAX
# 0   John   10     USA    1200   10  100.0
# 1  peter   10      UK    1400   20  200.0
# 2  Steve   10   Paris    1900   10    NaN
# 3   Brad   20  Canada    2100   20  300.0
# 4  Smith   30   India     900   10  400.0
# 5  Hussy   30   Dubai     800    4    NaN

# %%
# b = b.dropna()

# %%
b
# Out:
#     Name  Age    Area  Salary  EMI    TAX
# 0   John   10     USA    1200   10  100.0
# 1  peter   10      UK    1400   20  200.0
# 2  Steve   10   Paris    1900   10    NaN
# 3   Brad   20  Canada    2100   20  300.0
# 4  Smith   30   India     900   10  400.0
# 5  Hussy   30   Dubai     800    4    NaN

# %%
b['TAX'] = b['TAX'].fillna(20)

# %%
b
# Out:
#     Name  Age    Area  Salary  EMI    TAX
# 0   John   10     USA    1200   10  100.0
# 1  peter   10      UK    1400   20  200.0
# 2  Steve   10   Paris    1900   10   20.0
# 3   Brad   20  Canada    2100   20  300.0
# 4  Smith   30   India     900   10  400.0
# 5  Hussy   30   Dubai     800    4   20.0

# %%
b.to_csv('Own_data.csv',index=False)

# %% [markdown]
# - `we can create our own data and we can do manipulation and we can save the data `
#
# - `Insted of creating the data on our own we can load the data from exsheet and we can do manipulations on that data and we can finally save the data but we cant change the original one`

# %%
df = pd.read_csv('/content/Titanic-Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df = df.drop(['PassengerId','Name','Ticket'],axis=1)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Cabin     204 non-null    object
#  8   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
# head
df.head() # first 5
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
df.tail(3) # last 5
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch   Fare Cabin Embarked
# 888         0       3  female   NaN      1      2  23.45   NaN        S
# 889         1       1    male  26.0      0      0  30.00  C148        C
# 890         0       3    male  32.0      0      0   7.75   NaN        Q

# %%
df.sample(5)
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch    Fare Cabin Embarked
# 80          0       3  male  22.0      0      0  9.0000   NaN        S
# 592         0       3  male  47.0      0      0  7.2500   NaN        S
# 756         0       3  male  28.0      0      0  7.7958   NaN        S
# 466         0       2  male   NaN      0      0  0.0000   NaN        S
# 784         0       3  male  25.0      0      0  7.0500   NaN        S

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
577 + 314
# Out:
# 891

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (183, 9)

# %%
df.sample(7)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare        Cabin  \
# 27          0       1    male  19.0      3      2  263.0000  C23 C25 C27
# 341         1       1  female  24.0      3      2  263.0000  C23 C25 C27
# 205         0       3  female   2.0      0      1   10.4625           G6
# 647         1       1    male  56.0      0      0   35.5000          A26
# 11          1       1  female  58.0      0      0   26.5500         C103
# 257         1       1  female  30.0      0      0   86.5000          B77
# 717         1       2  female  27.0      0      0   10.5000         E101
#
#     Embarked
# 27         S
# 341        S
# 205        S
# 647        C
# 11         S
# 257        S
# 717        S

# %%
num_cols = df.select_dtypes(exclude='object')
text_cols = df.select_dtypes(include='object')

# %%
text_cols
# Out:
#         Sex        Cabin Embarked
# 1    female          C85        C
# 3    female         C123        S
# 6      male          E46        S
# 10   female           G6        S
# 11   female         C103        S
# ..      ...          ...      ...
# 871  female          D35        S
# 872    male  B51 B53 B55        S
# 879  female          C50        C
# 887  female          B42        S
# 889    male         C148        C
#
# [183 rows x 3 columns]

# %%
num_cols
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare
# 1           1       1  38.0      1      0  71.2833
# 3           1       1  35.0      1      0  53.1000
# 6           0       1  54.0      0      0  51.8625
# 10          1       3   4.0      1      1  16.7000
# 11          1       1  58.0      0      0  26.5500
# ..        ...     ...   ...    ...    ...      ...
# 871         1       1  47.0      1      1  52.5542
# 872         0       1  33.0      0      0   5.0000
# 879         1       1  56.0      0      1  83.1583
# 887         1       1  19.0      0      0  30.0000
# 889         1       1  26.0      0      0  30.0000
#
# [183 rows x 6 columns]

# %%
df.to_csv('cleaned_titanic_data.csv',index=False)

# %%
# GroupBy

df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.]})

df
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
df.groupby(['Animal']).mean()
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %%
df['Animal'].unique()
# Out:
# array(['Falcon', 'Parrot'], dtype=object)

# %%
df['Animal'].value_counts()
# Out:
# Animal
# Falcon    2
# Parrot    2
# Name: count, dtype: int64
