# %% [markdown]
# **Operators**
#
# `Means which is used to do some common math calculations`
#
# `+,-,/,//,%,*,**,>,<,<=,>=,!=,and,or,pow`

# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %%
10 + 20
# Out:
# 30

# %%
1 + 2 + 5 + 11
# Out:
# 19

# %%
10 - 20
# Out:
# -10

# %%
5 * 4
# Out:
# 20

# %%
2 * 5
# Out:
# 10

# %%
2 ** 5
# Out:
# 32

# %%
22 / 5
# Out:
# 4.4

# %%
22 // 5
# Out:
# 4

# %%
22 % 5
# Out:
# 2

# %%
17 / 4
# Out:
# 4.25

# %%
17 // 4
# Out:
# 4

# %%
17 % 4
# Out:
# 1

# %%
10 > 20
# Out:
# False

# %%
10 < 20
# Out:
# True

# %%
a = 10

# %%
10 == 9
# Out:
# False

# %%
10 == 10
# Out:
# True

# %%
10 >= 7
# Out:
# True

# %%
12 >= 34
# Out:
# False

# %%
10 != 7
# Out:
# True

# %%
10 >= 5 or 11 <= 7
# Out:
# True

# %%
50 >= 100 or 61 >= 78
# Out:
# False

# %%
10 >= 5 and 11 <= 7
# Out:
# False

# %%
50 >= 100 and 61 >= 78
# Out:
# False

# %%
import math # opening

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
len(dir(math))
# Out:
# 66

# %%
math.factorial(5)
# Out:
# 120

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
2 ** 5
# Out:
# 32

# %%
pow(2,5)
# Out:
# 32

# %%
pow(2,5,5)
# Out:
# 2

# %%
pow(2,5,5,10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-401817854.py in <cell line: 0>()
# ----> 1 pow(2,5,5,10)
#
# TypeError: pow() takes at most 3 arguments (4 given)

# %% [markdown]
# **print conditions**
#
# `How can we create the relationship between data types inside the print condition `

# %% [markdown]
# - `type_1 : using comma(,) we can create relationships with data types | comma will give one tab space `
#
# - `type_2 : using + operator we can create relation but if we want to create a relation using + both side should be + only and it will not give one tab space `
#
# - `type_3 : using f and {}`

# %%
r = 10
print('data',r)
# Out:
# data 10

# %%
f = 47

print('My name is ajay and my age is',f)
# Out:
# My name is ajay and my age is 47

# %%
course = 'data science'
time = 6
duration = 1.5

# expected output= I am learning data science with 6 months for 1.5 hours class daily

print('I am learning',course,'with',time,'months for',duration,'hours class daily')
# Out:
# I am learning data science with 6 months for 1.5 hours class daily

# %%
print('datascience',6,1.5)
# Out:
# datascience 6 1.5

# %%
f = 47

print('My name is ajay and my age is '+str(f))
# Out:
# My name is ajay and my age is 47

# %%
course = 'data science'
time = 6
duration = 1.5

# expected output= I am learning data science with 6 months for 1.5 hours class daily

print('I am learning '+course+' with '+str(time)+' months for '+str(duration)+' hours class daily')
# Out:
# I am learning data science with 6 months for 1.5 hours class daily

# %%
f = 47

print(f'My name is ajay and my age is {f}')
# Out:
# My name is ajay and my age is 47

# %%
course = 'data science'
time = 6
duration = 1.5

# expected output= I am learning data science with 6 months for 1.5 hours class daily

print(f'I am learning {course} with {time} months for {duration} hours class daily')
# Out:
# I am learning data science with 6 months for 1.5 hours class daily
